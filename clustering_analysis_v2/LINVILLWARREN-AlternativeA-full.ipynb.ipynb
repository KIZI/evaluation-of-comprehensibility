# %% [markdown]
# # Intro
# This version of the noteook contains alternative results for the Linvill dataset.
# * All tweets per account were used
# * Remaining setting the same as for the analysis using a subset of 100 tweets per account.

# %%
import re
from collections import OrderedDict
from nltk import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS
import pandas as pd
MAX_WORDS_WORDCLOUD =100
#

# %%
dataset_to_process = "LINVILL" # "MANNHEIM" LINVILL

# %%
from sqlalchemy import create_engine, inspect
engine = create_engine(f'sqlite:///{dataset_to_process}2full.sqlite')
connection = engine.connect()
print(engine.table_names())
inspector = inspect(connection)
# Out:
# []

# %% [markdown]
# # Loading of dataset from Helm and Paulheim

# %%
if dataset_to_process == "MANNHEIM":
    CLUSTERS_TO_TRY=[5,6,7]
    MINIMUM_TWEETS_PER_ACCOUNT=1
    PROCESS_MAX_TWEETS_PER_ACCOUNT=100000
    RANDOMIZE_TWEET_ORDER=False
    MIN_DF = 0.01 #0.4
    MAX_FEATURES= 100 #100
    overrideClusterSelection = "random6cosine"

# %% [markdown]
# The dataset is described at https://github.com/s-helm/TwitterFakeNews,  but the data need to be downloaded from http://data.dws.informatik.uni-mannheim.de/fakenews/.

# %%
if dataset_to_process == "MANNHEIM":
    tablename = "tweets"
    if not tablename in engine.table_names():
        inputFile = "mannheim/data_set_tweet_user_features.csv"
        df = pd.read_csv(inputFile, sep=";")
        df.to_sql(name=tablename, con=connection, if_exists='append', index=True)
    else:
        print("already present in database")

# %% [markdown]
# ### Rename the fields so that the names match names used in Linvill and Warren

# %%
if dataset_to_process == "MANNHEIM":
    columns = inspector.get_columns(tablename)
    colnames =[]
    for column in columns:
        colnames.append(column["name"])
    if "tweet__sent_tokenized_text" in colnames: 
        troll_sql = f"""
        ALTER TABLE '{tablename}'
        RENAME COLUMN tweet__sent_tokenized_text to content;"""
        cursor = connection.execute(troll_sql)
        troll_sql = f"""
            ALTER TABLE '{tablename}'
            RENAME COLUMN user__screen_name to author;"""
        cursor = connection.execute(troll_sql)
    if "tweet__lang" in colnames: 
        troll_sql = f"""
        ALTER TABLE '{tablename}'
        RENAME COLUMN tweet__lang to language;"""
        cursor = connection.execute(troll_sql)
    # here the category is fake or not fake, different from Linvill and Warren
    # todo: check if all tweets of the account are marked as fake if at least one is marked as fake 
    if "tweet__fake" in colnames: 
        troll_sql = f"""
        ALTER TABLE '{tablename}'
        RENAME COLUMN tweet__fake to account_category;"""
        cursor = connection.execute(troll_sql)
    # Not sure if tweet__retweeted corresponds to retweet
    if "tweet__retweeted" in colnames: 
        troll_sql = f"""
            ALTER TABLE '{tablename}'
            RENAME COLUMN tweet__retweeted to retweet;"""
        cursor = connection.execute(troll_sql)

# %% [markdown]
# # Loading of dataset from Linvill and Warren

# %% [markdown]
# The dataset needs to be copied from https://github.com/fivethirtyeight/russian-troll-tweets

# %%
if dataset_to_process == "LINVILL":
    CLUSTERS_TO_TRY=[5,6]
    MINIMUM_TWEETS_PER_ACCOUNT=100 # use only accounts with greater than this tweets
    PROCESS_MAX_TWEETS_PER_ACCOUNT = 100000 #100
    RANDOMIZE_TWEET_ORDER=True
    MIN_DF = 0.4 #as in the original experiment for user study
    MAX_FEATURES= None #as in the original experiment for user study
    overrideClusterSelection = "random6cosine"
    tablename= "tweets"
    if not tablename in engine.table_names():
        for i in range(1,14):
            inputFile = "russian-troll-tweets-master/IRAhandle_tweets_" + str(i) +".csv"
            print(inputFile)
            df = pd.read_csv(inputFile)
            #print("randomly selecting subset of data")
            #df=df.sample(random_state=42,frac=0.01)
            df.to_sql(name=tablename, con=connection, if_exists='append', index=True)
    else:
        print("already present in database")
# Out:
# russian-troll-tweets-master/IRAhandle_tweets_1.csv
# russian-troll-tweets-master/IRAhandle_tweets_2.csv
# russian-troll-tweets-master/IRAhandle_tweets_3.csv
# russian-troll-tweets-master/IRAhandle_tweets_4.csv
# russian-troll-tweets-master/IRAhandle_tweets_5.csv
# /home/tomas/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0,15,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# russian-troll-tweets-master/IRAhandle_tweets_6.csv
# russian-troll-tweets-master/IRAhandle_tweets_7.csv
# russian-troll-tweets-master/IRAhandle_tweets_8.csv
# russian-troll-tweets-master/IRAhandle_tweets_9.csv
# russian-troll-tweets-master/IRAhandle_tweets_10.csv
# /home/tomas/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# russian-troll-tweets-master/IRAhandle_tweets_11.csv
# russian-troll-tweets-master/IRAhandle_tweets_12.csv
# /home/tomas/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (10,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# russian-troll-tweets-master/IRAhandle_tweets_13.csv

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Total acounts, tweets, and average number of tweets per category

# %%
# selects number of accounts and number of tweets, average number of tweets per account (English tweets without retweets)
troll_sql = """
select account_category, count(*) as total_accounts, sum(tweet_cnt), sum(tweet_cnt)/count(*) 
as avg_tweets_per_account   from (
select
 account_category, author, count(*) as tweet_cnt
from tweets
where retweet = 0 and (language = 'English' or language = 'en')
group by account_category, author) 
group by account_category
"""
cursor = connection.execute(troll_sql)
result = cursor.fetchall()
result
# Out:
# [('Commercial', 5, 105928, 21185),
#  ('Fearmonger', 123, 9549, 77),
#  ('HashtagGamer', 110, 67387, 612),
#  ('LeftTroll', 227, 76365, 336),
#  ('NewsFeed', 49, 595561, 12154),
#  ('NonEnglish', 264, 5768, 21),
#  ('RightTroll', 622, 399850, 642),
#  ('Unknown', 173, 3923, 22)]

# %% [markdown]
# ## Total acounts, tweets, and average number of tweets per category considering only accounts with preset minimum number of tweets

# %%
# selects number of accounts and number of tweets, average number of tweets per account (English tweets without retweets)
# ONLY
troll_sql = f"""
select account_category, count(*) as total_accounts, sum(tweet_cnt), sum(tweet_cnt)/count(*) 
as avg_tweets_per_account   from (
select
 account_category, author, count(*) as tweet_cnt
from tweets
where retweet = 0 and (language = 'English' or language = 'en')
group by account_category, author
) 
where tweet_cnt >= {MINIMUM_TWEETS_PER_ACCOUNT} 
group by account_category 
"""
cursor = connection.execute(troll_sql)
result = cursor.fetchall()
result
# Out:
# [('Commercial', 4, 105926, 26481),
#  ('Fearmonger', 37, 5612, 151),
#  ('HashtagGamer', 63, 66192, 1050),
#  ('LeftTroll', 125, 73479, 587),
#  ('NewsFeed', 47, 595434, 12668),
#  ('NonEnglish', 12, 3297, 274),
#  ('RightTroll', 283, 389618, 1376),
#  ('Unknown', 7, 1339, 191)]

# %% [markdown]
# ## Are there any accounts with tweets in more than one category?

# %%
# selects number of accounts and number of tweets, average number of tweets per account (English tweets without retweets)
mixed_cats = f"""
select author from 
(select
 count(DISTINCT account_category) as cats, author
from tweets
where retweet = 0 and (language = 'English' or language = 'en') 
group by author)
where 
cats!=1
"""
cursor = connection.execute(mixed_cats)
authors_mix_result = cursor.fetchall()
authors_mix = [a[0]  for a in authors_mix_result]

# %%
# Yes for Helm and Paulheim, No for Linvill and Warren

# %%
authors_mix
# Out:
# []

# %% [markdown]
# # Create a new table for distinct authors

# %%
tablename= "tweets_authors"
troll_sql = """drop table IF EXISTS tweets_authors;"""
cursor = connection.execute(troll_sql)
troll_sql = """
create table tweets_authors as
select
author, account_category, count(*) as tweet_cnt
from tweets
where retweet = 0 and (language = 'English' or language = 'en')
group by author;"""
cursor = connection.execute(troll_sql)

# %%
cursor = connection.execute(f"select author from tweets_authors where tweet_cnt >= {MINIMUM_TWEETS_PER_ACCOUNT}")
authors = [author for (author, ) in cursor]
len(authors)
# Out:
# 578

# %%
tablename= "tweets_sample"
troll_sql = """drop table IF EXISTS tweets_sample;"""
cursor = connection.execute(troll_sql)

if RANDOMIZE_TWEET_ORDER:
    randSQL="order by random()"
else:
    randSQL = ""
if not tablename in engine.table_names(): # this line is not needed if the drop is present
    connection.execute(f"CREATE TABLE tweets_sample (content varchar({PROCESS_MAX_TWEETS_PER_ACCOUNT * 150}), author varchar(255), account_category varchar(255));")
    for author in authors:
        print(author)
        connection.execute(f"""
        insert into tweets_sample (content, author, account_category)
        select content, author, account_category from tweets
        where author = '{author}' 
        {randSQL} limit {PROCESS_MAX_TWEETS_PER_ACCOUNT};
        """)
        r= connection.execute(f"""
        select count(*) from tweets_sample
        """)
# Out:
# 10_GOP
# 4MYSQUAD
# AANTIRACIST
# ABIGAILSSILK
# ABIISSROSB
# ABMERRLINS
# ACAB_ZONE
# ACAPARELLA
# ACEJINEV
# ADAMCHAPMANJR
# ADDIE_HOL
# ADELE_BROCK
# ADNNELSTR
# ADRGREERR
# ADRIASNSS
# ADRIENNE_GG
# AFEELIUTR
# AIDEN7757
# ALANISSTRS
# ALAXXATR
# ALBERTMORENMORE
# ALBUQUERQUEON
# ALDRICH420
# ALECMOOOOODY
# ALEXXDRTRR
# ALIISTRR
# ALLBERRTOSS
# AMANDAVGREEN
# AMBBERTHTT
# AMBERLINETR
# AMBERRPAR
# AMCONVOICE
# AMELIEBALDWIN
# AMELINAASTR
# AMERICANALBERT
# AMIISTRS
# AMYYSLEGENTR
# ANAAISLEC
# ANAALESSIS
# ANASTASSITR
# ANCARICTRS
# ANDEERLWR
# ANDIOSMARRTRUMP
# ANDRISNABRT
# ANDRREETRT
# ANDYDREWDANIELS
# ANDYHASHTAGGER
# ANGEELISTR
# ANGELISTRR
# ANGISDOOYL
# ANGTHEESTR
# ANIIANTRS
# ANISACRRUTR
# ANISILOPE
# ANISSNOVOTR
# ANNAMINGT
# ANNIEPOSHES
# ANNIJONSTR
# ANTONHAYHAY
# ANTONRUMSS
# ANZGRI
# APRRILSBRUSS
# ARABMTR
# ARAGARTRR
# ARCHIEOLIVERS
# ARIAANST
# ARIEENSLPE
# ARISGRAYS
# ARM_2_ALAN
# ARTEMSSFE
# ASHLEEYWES
# ASWWIMMORRIS
# ATLANTA_ONLINE
# AURRLISTR
# AUSTINLOVESBEER
# AYLEENSCLAR
# AZUUMARSS
# BABYJANNYMEOW
# BALTIMORE0NLINE
# BAMMBJOLTR
# BAOBAEHAM
# BARBARAFORTRUMP
# BARELYBARBOZA
# BARRLAUTRS
# BATONROUGEVOICE
# BEAUTYMERCELA
# BECCYWILL
# BEEATRWL
# BEEBCLAPTT
# BEETTYBECKS
# BEREHAYYTR
# BERLINBOTE
# BERRNICTRR
# BEVERLYBALSOM
# BGARNER2107
# BIAANCLEESS
# BIGBOYJASIAH
# BIGBOYSNEED
# BIGSEANBEAST
# BISHOLORINE
# BIZGOD
# BLACKEYEBLOG
# BLACKMATTERSUS
# BLACKNEWSOUTLET
# BLACKTIVISTS
# BLACKTIVISTSUS
# BLACKTOLIVE
# BLACK_ELEVATION
# BLACNEIGHBOR
# BLEEPTHEPOLICE
# BLMSOLDIER
# BOOTH_PRINCE
# BRENTMCCLURE275
# BRIANAREGLAND
# BRIANTHELIFTER
# BRIANWARNING
# BRICEGELLER
# BRIGHTANDGLORY
# BRIGHTNOOM
# BRIIGEVASTR
# BRIISTATRRT
# BRISSTOFLR
# BROSELIFOTR
# BRRISTASI
# BRUCIEDUBLIN
# CAADEENRRS
# CAARMBUTL
# CADDEETRS
# CALEBPAAR
# CALIFRONIAREP
# CAMDENCITYNEWS
# CAMEERICLAAR
# CAMELIISRT
# CAMOSASEKO
# CANDEYCHANEY
# CANDISMBRR
# CANNONSHER
# CARIISNCISTR
# CARLLTHERITR
# CARRIETHORNTHON
# CASCASEYP
# CASSANDRDR
# CASSIEWELTCH
# CASSISHERE
# CATELINEWATKINS
# CATHERINECALLS
# CATTSADSTR
# CECIIISTATS
# CELIISSGONS
# CELLESTINS
# CELLSSTITR
# CHAASNTR
# CHADSLOYER
# CHARLESJHARPER
# CHARMEESTRS
# CHARRISSTR
# CHEELSYJOTRS
# CHELSSJOHNT
# CHESPLAYSCHESS
# CHESTERCITYNEWS
# CHICAGOBL
# CHICAGODAILYNEW
# CHIRRISMOGUI
# CHIRRMORRE
# CHRISTINACRISSS
# CHRIXCHASE
# CHRIXMORGAN
# CLAARISRTR
# CLAUDIA42KERN
# CLAYPAIGEBOO
# CLIFTONHUGHES_
# CLYDEDAWS0N
# COLBYST1
# COLINSNEVERLAND
# COOKIIIEEESSSS
# COOKNCOOKS
# CORNELLBURCHET
# CORYNAENAE
# COVFEFENATIONUS
# CRYSTAL1JOHNSON
# CURTISBIGMAN
# CYNTHIAMHUNTER
# C__WELLS
# DAILEYJADON
# DAILYLOSANGELES
# DAILYNEWSDENVER
# DAILYSANDIEGO
# DAILYSANFRAN
# DAILYSANJOSE
# DALLASTOPNEWS
# DAMANIMILES
# DANAGEEZUS
# DANISSTRS
# DANNYTHEHAPPIES
# DANNY_TURNER_1
# DAPNESSTR
# DARCYYSTR
# DARKNALLY
# DATWISENIGGA
# DAUMOA
# DAVBOYD_
# DD_MERR
# DEBESSTRS
# DEBORRTH
# DESERTQUEENOH
# DETROITDAILYNEW
# DEUSXYX
# DEVINEDEVINBR
# DICKYIRWIN
# DINGDONPARKER
# DJKATKATKATIE
# DOMINICVALENT
# DONNABRIVERA
# DONNIELMILLER
# DONTSHOOTCOM
# DOROTHIEBELL
# DORTHYSHARRER
# DOYRANDO
# DRMICHAELGARCIA
# DUTISITE
# DYBAIGWEN
# EDMUNDC0OKE
# EDMUNDRJR
# EDWARDBROBERTS
# EISSYT56T
# ELIANLINDSEY
# ELIASBRICK
# ELINSSTR
# ELIZEESTR
# ELLASTRS
# ELMA_ELMAMA
# ELPASOTOPNEWS
# EMELDDTRS
# EMILEEWAREN
# EMILLLYSTRU
# EMMAJACKT
# EMMA_FSSXX
# ERICARUTTER
# ERRIVVVVERS
# EVAGREEN69
# EVANNGHARTR
# EVANS_TAB
# EVEWEBSTER373
# EXQUOTE
# FAIRYMINKY
# FAMEONYOUBITCH
# FIGHTM_D_B
# FIGHTTORESIST
# FINDDIET
# FINNAGLO
# FLOYDSWENSON555
# FORCEOFLIBERTY
# FRANCESCAVAND
# FREEDISCUSS
# FUNDDIET
# GAB1ALDANA
# GABIJENSEN91
# GAB_ARTEA_G
# GAGYSOKEFUV
# GALLOWAYELIANA
# GARRETTSIMPSON_
# GEPADIKULAXE
# GERTY_HAWA
# GIBBS_JEREMY_
# GLADADILA
# GLENNHARPER_
# GLOBALFOE
# GL_WORKMAN
# GRACELILSTAR
# GRAYS0NWILDE
# GUNS4LIFE_ME
# GWENNYTHOT
# HAMBURGBOTE
# HANDSOME_HENSON
# HAPPKENDRAHAPPY
# HARVEYRYAN92
# HATTIEB78
# HAWORYMYHAK
# HELLIEEDWARDS
# HENY_AMBERH
# HEYHEYHAILEY
# HEYITSGLOR
# HEYITS_TOBY
# HIIMKHLOE
# HIPPPO_
# HOLDMEJERRY
# HOLLANDPATRICKK
# HOLLYDLER
# HOLYCRAPCHRIX
# HOUSTONTOPNEWS
# HUNTERODDDDOM
# HYDDROX
# IANCALH0UN
# IGNITEDFIRESTAR
# IIDDAAMARKS
# ILIKEBIGBUTTAND
# ILOVESARAHRICH
# IMAPHARRELFAKE
# IMASWERVE
# IMISSOBAMA
# IMOGEENTR
# INSTOTUS
# INST_VETS
# INTERFISCHER
# ISABEL_STAFF
# ISA_BELLA_GR
# ISRAEL_WILLS
# ITSTIMETOSECEDE
# IVAASSNTR
# J0HNLARSEN
# JACKSONCITYPOST
# JACQUELINISBEST
# JADONHUTCHINSON
# JAEDENMASSEY
# JAMIE_MCCARTHY_
# JANELPERKINSON
# JANI_S_JAC
# JANSKEESTR
# JARRARDNORMAN
# JASPER_FLY
# JASSSCOTT
# JAVONHIDP
# JAYDAASTONISHIN
# JEANETTEDBOLDEN
# JEANNEMCCARTHY0
# JEANUTTELLA
# JEBLARY2016
# JEFFREYKAHUNAS
# JEMISHAAAZZZ
# JENN_ABRAMS
# JERSTONER
# JERY_ROBERTSYO
# JESSYBOWWOW
# JIHADIST2NDWIFE
# JMCD0WELL
# JMSCOXXX
# JOHAAJOTS
# JOHNBRANCHH
# JOHNCOPPER16
# JOHNIEBOYCOOKS
# JOHNIEVOGUE
# JOHNNYMARCH_
# JON_UNDERWOOD_
# JOSEPH_JENKS
# JOTEFOKIS
# JSHMRTNEZ
# JSNCAREY
# JUANTHOMSSTRUMT
# JUDELAMBERTUSA
# JUSMASXTRT
# JUSTBE_MINE
# KAHALEETR
# KANIJJACKSON
# KANSASDAILYNEWS
# KARENPARKER93
# KARMAISABITCHH1
# KATEDEBROOK
# KATERITTERRRR
# KATHIEMRR
# KAYDENMELTON
# KELVIN_CHAMBERS
# KENCANNONE
# KENDRAGRRR
# KENZDONOVAN
# KIRSTENLADANIEL
# KRISTYANANN
# LACHRISTIE
# LAGONEHOE
# LARAHARRRRISON
# LAURABAELEY
# LAWWAANCTR
# LAZYKSTAFFORD
# LELANDGRAVES_
# LEROYLOVESUSA
# LGBTUNI
# LGBTUNITEDCOM
# LILAASTRS
# LILJORDAMN
# LIRASTERTTRUMP
# LNEVER_MINDL
# LOGAN_WHATSUP
# LOLA_AYERS_
# LOOKATMEZERO
# LORAGREEEN
# LUCEELYSTOP
# LUCYTRUMPTTOP56
# LUGHHALLEY
# LUZMARTRUMPPT
# LYNDAWKING
# LYNSRODRIGUEZ
# MALLBOWEN
# MALLORYJARED
# MANDY9STEVENS
# MANZAL_
# MAORBRIGHTIE
# MARCH_FOR_TRUMP
# MARIALOPTRUMP
# MARIATRUMPT
# MARISSAIMSTRONG
# MARISSPRT
# MARKMCGREGORY
# MARLEY_SHN
# MARRISSATRR
# MARTINES_TWEETS
# MARTINIVINE
# MATEVIDENCE
# MAYLUUSSTR
# MAYMAYMYY
# MEGGIEONEIL
# MELANYMELANIN
# MELVINSROBERTS
# MEMYSELFHAILEY
# MICHELLEARRY
# MICPARRISH
# MIL0BLAKE
# MILWAUKEEVOICE
# MINNEAPOLISON
# MISSOURINEWSUS
# MOM_0F_TWINS
# MONEYFORM
# MRCLYDEPRATT
# MRJACKSJACKSON
# MRMORAAN
# MR_CLAMPIN
# MSHEATHOWENS
# MUHAMMADMUSA23
# MUHSANSINS
# MUSLIMS_IN_USA
# NEHEMIAHX
# NEVERLIET0ME
# NEWARKVOICE
# NEWORLEANSON
# NEWSPEAKDAILY
# NEWYORKDEM
# NJ_BLACKNEWS
# NOJONATHONNO
# NORMAN_HOOPER
# NOTBALLINYET
# NOTRITAHART
# NOVOSTILAVROV
# OAKLANDONLINE
# OGDEANDRE
# OLIVIA1GB
# OLIVIADWARREN
# ONEMIGHTYFISH
# ONLINECLEVELAND
# ONLINEMEMPHIS
# ORRCLAY
# OSCAR_ROWE_
# PAIGE_JAM
# PAMBLMDANIELS
# PAMELAKEALER13
# PAMELA_MOORE13
# PAMELA_SHARKY13
# PAOLAKINCK
# PATI_COOPER
# PATRIOTBLAKE
# PATRIOTOTUS
# PAULINETT
# PEYTONCASHOUT
# PHILADELPHIAON
# PHOENIXDAILYNEW
# PIGEONTODAY
# POLICESTATEME
# POLIGRAPHME
# POLITWEECS
# PORTMELA
# PRETTYLARAPLACE
# PRETTYSASHAH
# PRICEFORPIERCE
# PROJECTLANDY
# PRUITT_LI
# PUREDAVIE
# QUEENNARIELLE
# QUEENOFTHEWO
# RADEKESOFIA
# RAMONASNAILS
# RANDOLPHBURRR
# RAVENICHOLSON
# REACHITDOIT
# REALROBERT1987
# REALTEN_GOP
# REDLANEWS
# REGIEBLACKMON
# RESISTERSUNION
# RH0LBR00K
# RICHMONDVOICE
# RIGHTNPR
# RIOGITHIEF
# RISSTYTRT
# RLOVENOSAUSE
# ROBERTEBONYKING
# ROBIN_MC_CALL
# ROOMOFRUMOR
# ROSCOE_RIDDLE
# ROSSIROSSIVIN
# RUS_IN_USA
# RYANMAXWELL_1
# SADIEEATONN
# SAMIRGOODEN
# SANANTOTOPNEWS
# SCARLETTHOWAR15
# SCREAMIN3
# SCREAMYMONKEY
# SEATTLE_POST
# SERGIO_MAESTRI
# SHEENA_OTT
# SHERLYMONMONC
# SHINEPHILLIPS
# SICCERTHANYOU
# SIENNASMM
# SINCEREPRUITT
# SINDYBLOSSOM
# SKWAD55_LABEL
# SOUTHLONESTAR
# SPECIALAFFAIR
# SRAHSE
# SSABRINAHUH
# SSUS_PANTHER
# STACEWATERS_
# STANLEYPARRIS
# STANLEY_COX_
# STAYWOKE88
# STINSON_SS
# STLOUISONLINE
# SUNSANB
# SUSAYUNG
# SWEETKERRY54
# T0NYASINCLAIR
# TAMMY_TAMH
# TEN_GOP
# TERESA_BOY_LE
# TESSYELMORE
# TESS_SNIDER
# THEFOUNDINGSON
# THELMMISB
# THEMANMACHINE17
# THETRAINGUY13
# TODAYBOSTONMA
# TODAYCINCINNATI
# TODAYCLEVELAND
# TODAYINSYRIA
# TODAYMIAMI
# TODAYNYCITY
# TODAYPITTSBURGH
# TOLLIVERSTEPH
# TONEPORTER
# TPARTYNEWS
# TRACEYHAPPYMOM
# TRAYNESHACOLE
# TRYTOFINDITOUT
# USA_GUNSLINGER
# VA_BLACKNEWS
# VEROSANRRT
# VESTIZAKHAROVA
# WADEHARRIOT
# WARFAREWW
# WASHINGTONLINE
# WATCHMEWALKIN
# WAYNE_DRAKE_
# WESTERNWINDWES
# WILDHAREE
# WILLIAMS8KALVIN
# WILLIAMS_DIANA_
# WILLISBONNERR
# WOKEFROMDAY1
# WOKELUISA
# WONDERHANN
# WORLDNEWSPOLI
# WORLDOFHASHTAGS
# XDWILLIE
# YAELTROUBLE
# YOUJUSTCTRLC
# ZZARACROSS
# ZZZACHARYZZZ
# _BILLY_MOYER_
# _NICKLUNA_
# _RUBY_WILLS_

# %% [markdown]
# #### check number of selected tweets

# %%
r= connection.execute(f"""
select count(*) from tweets_sample
""")
r.fetchall()
# Out:
# [(2105514,)]

# %% [markdown]
# # Processing of preselected tweets

# %% [markdown]
# ### tweets in account are merged into one text

# %%
sql = 'select author, content, account_category from tweets_sample order by author'
cursor= connection.execute(sql)
#result = cursor.fetchall()
documents_dict = OrderedDict()
true_labels = []
# merge all tweets by one author into one entry 
authors=0
tweets=0
for (author, content, account_category) in cursor:
    if dataset_to_process == "MANNHEIM":
        if account_category =="0":
            account_category="real news"
        else:
            account_category="fake news"
    if author in documents_dict:
        if content != None:
            tweets=tweets+1
            documents_dict[author] += '\n' + content
            #if the tweet is in a different category than previously seen for this author
            #then reassign the author to the "mixed" category
            #this is applicable only for the Mannheim dataset, where
            #for several accounts some tweets are marked as 0 and some as 1
            if true_labels[len(true_labels)-1]!="mixed" and account_category != true_labels[len(true_labels)-1]:
                true_labels[len(true_labels)-1] = "mixed"
        else:
            print("Skipped empty content")
    else:
        authors=authors+1
        tweets= tweets +1
        true_labels.append(account_category)
        documents_dict[author] = content
print("authors " + str(authors))
print("tweets " + str(tweets))
# Out:
# Skipped empty content
# authors 578
# tweets 2105513

# %%
from collections import Counter
Counter(true_labels)
# Out:
# Counter({'RightTroll': 283,
#          'LeftTroll': 125,
#          'HashtagGamer': 63,
#          'NewsFeed': 47,
#          'NonEnglish': 12,
#          'Fearmonger': 37,
#          'Commercial': 4,
#          'Unknown': 7})

# %%
list(zip(documents_dict.keys(),true_labels))
# Out:
# [('10_GOP', 'RightTroll'),
#  ('4MYSQUAD', 'LeftTroll'),
#  ('AANTIRACIST', 'LeftTroll'),
#  ('ABIGAILSSILK', 'HashtagGamer'),
#  ('ABIISSROSB', 'RightTroll'),
#  ('ABMERRLINS', 'RightTroll'),
#  ('ACAB_ZONE', 'LeftTroll'),
#  ('ACAPARELLA', 'RightTroll'),
#  ('ACEJINEV', 'LeftTroll'),
#  ('ADAMCHAPMANJR', 'LeftTroll'),
#  ('ADDIE_HOL', 'RightTroll'),
#  ('ADELE_BROCK', 'RightTroll'),
#  ('ADNNELSTR', 'RightTroll'),
#  ('ADRGREERR', 'LeftTroll'),
#  ('ADRIASNSS', 'RightTroll'),
#  ('ADRIENNE_GG', 'HashtagGamer'),
#  ('AFEELIUTR', 'RightTroll'),
#  ('AIDEN7757', 'HashtagGamer'),
#  ('ALANISSTRS', 'RightTroll'),
#  ('ALAXXATR', 'RightTroll'),
#  ('ALBERTMORENMORE', 'RightTroll'),
#  ('ALBUQUERQUEON', 'NewsFeed'),
#  ('ALDRICH420', 'RightTroll'),
#  ('ALECMOOOOODY', 'LeftTroll'),
#  ('ALEXXDRTRR', 'RightTroll'),
#  ('ALIISTRR', 'RightTroll'),
#  ('ALLBERRTOSS', 'RightTroll'),
#  ('AMANDAVGREEN', 'HashtagGamer'),
#  ('AMBBERTHTT', 'RightTroll'),
#  ('AMBERLINETR', 'RightTroll'),
#  ('AMBERRPAR', 'RightTroll'),
#  ('AMCONVOICE', 'RightTroll'),
#  ('AMELIEBALDWIN', 'RightTroll'),
#  ('AMELINAASTR', 'RightTroll'),
#  ('AMERICANALBERT', 'RightTroll'),
#  ('AMIISTRS', 'RightTroll'),
#  ('AMYYSLEGENTR', 'RightTroll'),
#  ('ANAAISLEC', 'RightTroll'),
#  ('ANAALESSIS', 'RightTroll'),
#  ('ANASTASSITR', 'RightTroll'),
#  ('ANCARICTRS', 'RightTroll'),
#  ('ANDEERLWR', 'RightTroll'),
#  ('ANDIOSMARRTRUMP', 'RightTroll'),
#  ('ANDRISNABRT', 'RightTroll'),
#  ('ANDRREETRT', 'RightTroll'),
#  ('ANDYDREWDANIELS', 'HashtagGamer'),
#  ('ANDYHASHTAGGER', 'HashtagGamer'),
#  ('ANGEELISTR', 'RightTroll'),
#  ('ANGELISTRR', 'RightTroll'),
#  ('ANGISDOOYL', 'RightTroll'),
#  ('ANGTHEESTR', 'RightTroll'),
#  ('ANIIANTRS', 'RightTroll'),
#  ('ANISACRRUTR', 'RightTroll'),
#  ('ANISILOPE', 'RightTroll'),
#  ('ANISSNOVOTR', 'RightTroll'),
#  ('ANNAMINGT', 'RightTroll'),
#  ('ANNIEPOSHES', 'HashtagGamer'),
#  ('ANNIJONSTR', 'RightTroll'),
#  ('ANTONHAYHAY', 'LeftTroll'),
#  ('ANTONRUMSS', 'RightTroll'),
#  ('ANZGRI', 'NonEnglish'),
#  ('APRRILSBRUSS', 'RightTroll'),
#  ('ARABMTR', 'RightTroll'),
#  ('ARAGARTRR', 'RightTroll'),
#  ('ARCHIEOLIVERS', 'RightTroll'),
#  ('ARIAANST', 'RightTroll'),
#  ('ARIEENSLPE', 'RightTroll'),
#  ('ARISGRAYS', 'RightTroll'),
#  ('ARM_2_ALAN', 'RightTroll'),
#  ('ARTEMSSFE', 'RightTroll'),
#  ('ASHLEEYWES', 'RightTroll'),
#  ('ASWWIMMORRIS', 'RightTroll'),
#  ('ATLANTA_ONLINE', 'NewsFeed'),
#  ('AURRLISTR', 'RightTroll'),
#  ('AUSTINLOVESBEER', 'RightTroll'),
#  ('AYLEENSCLAR', 'RightTroll'),
#  ('AZUUMARSS', 'RightTroll'),
#  ('BABYJANNYMEOW', 'HashtagGamer'),
#  ('BALTIMORE0NLINE', 'NewsFeed'),
#  ('BAMMBJOLTR', 'RightTroll'),
#  ('BAOBAEHAM', 'LeftTroll'),
#  ('BARBARAFORTRUMP', 'RightTroll'),
#  ('BARELYBARBOZA', 'Fearmonger'),
#  ('BARRLAUTRS', 'RightTroll'),
#  ('BATONROUGEVOICE', 'NewsFeed'),
#  ('BEAUTYMERCELA', 'RightTroll'),
#  ('BECCYWILL', 'RightTroll'),
#  ('BEEATRWL', 'RightTroll'),
#  ('BEEBCLAPTT', 'RightTroll'),
#  ('BEETTYBECKS', 'RightTroll'),
#  ('BEREHAYYTR', 'RightTroll'),
#  ('BERLINBOTE', 'NonEnglish'),
#  ('BERRNICTRR', 'RightTroll'),
#  ('BEVERLYBALSOM', 'Fearmonger'),
#  ('BGARNER2107', 'HashtagGamer'),
#  ('BIAANCLEESS', 'RightTroll'),
#  ('BIGBOYJASIAH', 'LeftTroll'),
#  ('BIGBOYSNEED', 'LeftTroll'),
#  ('BIGSEANBEAST', 'LeftTroll'),
#  ('BISHOLORINE', 'RightTroll'),
#  ('BIZGOD', 'Commercial'),
#  ('BLACKEYEBLOG', 'LeftTroll'),
#  ('BLACKMATTERSUS', 'LeftTroll'),
#  ('BLACKNEWSOUTLET', 'LeftTroll'),
#  ('BLACKTIVISTS', 'LeftTroll'),
#  ('BLACKTIVISTSUS', 'LeftTroll'),
#  ('BLACKTOLIVE', 'LeftTroll'),
#  ('BLACK_ELEVATION', 'LeftTroll'),
#  ('BLACNEIGHBOR', 'LeftTroll'),
#  ('BLEEPTHEPOLICE', 'LeftTroll'),
#  ('BLMSOLDIER', 'LeftTroll'),
#  ('BOOTH_PRINCE', 'HashtagGamer'),
#  ('BRENTMCCLURE275', 'LeftTroll'),
#  ('BRIANAREGLAND', 'LeftTroll'),
#  ('BRIANTHELIFTER', 'LeftTroll'),
#  ('BRIANWARNING', 'RightTroll'),
#  ('BRICEGELLER', 'LeftTroll'),
#  ('BRIGHTANDGLORY', 'HashtagGamer'),
#  ('BRIGHTNOOM', 'RightTroll'),
#  ('BRIIGEVASTR', 'RightTroll'),
#  ('BRIISTATRRT', 'RightTroll'),
#  ('BRISSTOFLR', 'RightTroll'),
#  ('BROSELIFOTR', 'RightTroll'),
#  ('BRRISTASI', 'RightTroll'),
#  ('BRUCIEDUBLIN', 'HashtagGamer'),
#  ('CAADEENRRS', 'RightTroll'),
#  ('CAARMBUTL', 'RightTroll'),
#  ('CADDEETRS', 'RightTroll'),
#  ('CALEBPAAR', 'HashtagGamer'),
#  ('CALIFRONIAREP', 'LeftTroll'),
#  ('CAMDENCITYNEWS', 'NewsFeed'),
#  ('CAMEERICLAAR', 'RightTroll'),
#  ('CAMELIISRT', 'RightTroll'),
#  ('CAMOSASEKO', 'LeftTroll'),
#  ('CANDEYCHANEY', 'HashtagGamer'),
#  ('CANDISMBRR', 'RightTroll'),
#  ('CANNONSHER', 'LeftTroll'),
#  ('CARIISNCISTR', 'RightTroll'),
#  ('CARLLTHERITR', 'RightTroll'),
#  ('CARRIETHORNTHON', 'RightTroll'),
#  ('CASCASEYP', 'HashtagGamer'),
#  ('CASSANDRDR', 'RightTroll'),
#  ('CASSIEWELTCH', 'HashtagGamer'),
#  ('CASSISHERE', 'RightTroll'),
#  ('CATELINEWATKINS', 'HashtagGamer'),
#  ('CATHERINECALLS', 'RightTroll'),
#  ('CATTSADSTR', 'RightTroll'),
#  ('CECIIISTATS', 'RightTroll'),
#  ('CELIISSGONS', 'RightTroll'),
#  ('CELLESTINS', 'RightTroll'),
#  ('CELLSSTITR', 'RightTroll'),
#  ('CHAASNTR', 'RightTroll'),
#  ('CHADSLOYER', 'LeftTroll'),
#  ('CHARLESJHARPER', 'HashtagGamer'),
#  ('CHARMEESTRS', 'RightTroll'),
#  ('CHARRISSTR', 'RightTroll'),
#  ('CHEELSYJOTRS', 'RightTroll'),
#  ('CHELSSJOHNT', 'RightTroll'),
#  ('CHESPLAYSCHESS', 'RightTroll'),
#  ('CHESTERCITYNEWS', 'NewsFeed'),
#  ('CHICAGOBL', 'LeftTroll'),
#  ('CHICAGODAILYNEW', 'NewsFeed'),
#  ('CHIRRISMOGUI', 'RightTroll'),
#  ('CHIRRMORRE', 'RightTroll'),
#  ('CHRISTINACRISSS', 'RightTroll'),
#  ('CHRIXCHASE', 'HashtagGamer'),
#  ('CHRIXMORGAN', 'HashtagGamer'),
#  ('CLAARISRTR', 'RightTroll'),
#  ('CLAUDIA42KERN', 'HashtagGamer'),
#  ('CLAYPAIGEBOO', 'LeftTroll'),
#  ('CLIFTONHUGHES_', 'LeftTroll'),
#  ('CLYDEDAWS0N', 'RightTroll'),
#  ('COLBYST1', 'RightTroll'),
#  ('COLINSNEVERLAND', 'RightTroll'),
#  ('COOKIIIEEESSSS', 'LeftTroll'),
#  ('COOKNCOOKS', 'RightTroll'),
#  ('CORNELLBURCHET', 'LeftTroll'),
#  ('CORYNAENAE', 'LeftTroll'),
#  ('COVFEFENATIONUS', 'RightTroll'),
#  ('CRYSTAL1JOHNSON', 'LeftTroll'),
#  ('CURTISBIGMAN', 'HashtagGamer'),
#  ('CYNTHIAMHUNTER', 'RightTroll'),
#  ('C__WELLS', 'RightTroll'),
#  ('DAILEYJADON', 'HashtagGamer'),
#  ('DAILYLOSANGELES', 'NewsFeed'),
#  ('DAILYNEWSDENVER', 'NewsFeed'),
#  ('DAILYSANDIEGO', 'NewsFeed'),
#  ('DAILYSANFRAN', 'NewsFeed'),
#  ('DAILYSANJOSE', 'NewsFeed'),
#  ('DALLASTOPNEWS', 'NewsFeed'),
#  ('DAMANIMILES', 'LeftTroll'),
#  ('DANAGEEZUS', 'HashtagGamer'),
#  ('DANISSTRS', 'RightTroll'),
#  ('DANNYTHEHAPPIES', 'HashtagGamer'),
#  ('DANNY_TURNER_1', 'RightTroll'),
#  ('DAPNESSTR', 'RightTroll'),
#  ('DARCYYSTR', 'RightTroll'),
#  ('DARKNALLY', 'NewsFeed'),
#  ('DATWISENIGGA', 'LeftTroll'),
#  ('DAUMOA', 'LeftTroll'),
#  ('DAVBOYD_', 'RightTroll'),
#  ('DD_MERR', 'Fearmonger'),
#  ('DEBESSTRS', 'RightTroll'),
#  ('DEBORRTH', 'RightTroll'),
#  ('DESERTQUEENOH', 'Fearmonger'),
#  ('DETROITDAILYNEW', 'NewsFeed'),
#  ('DEUSXYX', 'RightTroll'),
#  ('DEVINEDEVINBR', 'RightTroll'),
#  ('DICKYIRWIN', 'HashtagGamer'),
#  ('DINGDONPARKER', 'RightTroll'),
#  ('DJKATKATKATIE', 'RightTroll'),
#  ('DOMINICVALENT', 'HashtagGamer'),
#  ('DONNABRIVERA', 'RightTroll'),
#  ('DONNIELMILLER', 'HashtagGamer'),
#  ('DONTSHOOTCOM', 'LeftTroll'),
#  ('DOROTHIEBELL', 'RightTroll'),
#  ('DORTHYSHARRER', 'Fearmonger'),
#  ('DOYRANDO', 'Fearmonger'),
#  ('DRMICHAELGARCIA', 'LeftTroll'),
#  ('DUTISITE', 'RightTroll'),
#  ('DYBAIGWEN', 'Fearmonger'),
#  ('EDMUNDC0OKE', 'RightTroll'),
#  ('EDMUNDRJR', 'LeftTroll'),
#  ('EDWARDBROBERTS', 'RightTroll'),
#  ('EISSYT56T', 'RightTroll'),
#  ('ELIANLINDSEY', 'HashtagGamer'),
#  ('ELIASBRICK', 'LeftTroll'),
#  ('ELINSSTR', 'RightTroll'),
#  ('ELIZEESTR', 'RightTroll'),
#  ('ELLASTRS', 'RightTroll'),
#  ('ELMA_ELMAMA', 'RightTroll'),
#  ('ELPASOTOPNEWS', 'NewsFeed'),
#  ('EMELDDTRS', 'RightTroll'),
#  ('EMILEEWAREN', 'RightTroll'),
#  ('EMILLLYSTRU', 'RightTroll'),
#  ('EMMAJACKT', 'RightTroll'),
#  ('EMMA_FSSXX', 'RightTroll'),
#  ('ERICARUTTER', 'HashtagGamer'),
#  ('ERRIVVVVERS', 'LeftTroll'),
#  ('EVAGREEN69', 'RightTroll'),
#  ('EVANNGHARTR', 'RightTroll'),
#  ('EVANS_TAB', 'RightTroll'),
#  ('EVEWEBSTER373', 'RightTroll'),
#  ('EXQUOTE', 'Commercial'),
#  ('FAIRYMINKY', 'Fearmonger'),
#  ('FAMEONYOUBITCH', 'HashtagGamer'),
#  ('FIGHTM_D_B', 'LeftTroll'),
#  ('FIGHTTORESIST', 'LeftTroll'),
#  ('FINDDIET', 'Commercial'),
#  ('FINNAGLO', 'LeftTroll'),
#  ('FLOYDSWENSON555', 'Fearmonger'),
#  ('FORCEOFLIBERTY', 'RightTroll'),
#  ('FRANCESCAVAND', 'Fearmonger'),
#  ('FREEDISCUSS', 'RightTroll'),
#  ('FUNDDIET', 'Commercial'),
#  ('GAB1ALDANA', 'HashtagGamer'),
#  ('GABIJENSEN91', 'Fearmonger'),
#  ('GAB_ARTEA_G', 'Fearmonger'),
#  ('GAGYSOKEFUV', 'Fearmonger'),
#  ('GALLOWAYELIANA', 'LeftTroll'),
#  ('GARRETTSIMPSON_', 'RightTroll'),
#  ('GEPADIKULAXE', 'Fearmonger'),
#  ('GERTY_HAWA', 'Fearmonger'),
#  ('GIBBS_JEREMY_', 'RightTroll'),
#  ('GLADADILA', 'Fearmonger'),
#  ('GLENNHARPER_', 'RightTroll'),
#  ('GLOBALFOE', 'LeftTroll'),
#  ('GL_WORKMAN', 'Unknown'),
#  ('GRACELILSTAR', 'RightTroll'),
#  ('GRAYS0NWILDE', 'Fearmonger'),
#  ('GUNS4LIFE_ME', 'RightTroll'),
#  ('GWENNYTHOT', 'LeftTroll'),
#  ('HAMBURGBOTE', 'NonEnglish'),
#  ('HANDSOME_HENSON', 'RightTroll'),
#  ('HAPPKENDRAHAPPY', 'RightTroll'),
#  ('HARVEYRYAN92', 'Fearmonger'),
#  ('HATTIEB78', 'RightTroll'),
#  ('HAWORYMYHAK', 'Fearmonger'),
#  ('HELLIEEDWARDS', 'HashtagGamer'),
#  ('HENY_AMBERH', 'Fearmonger'),
#  ('HEYHEYHAILEY', 'HashtagGamer'),
#  ('HEYITSGLOR', 'RightTroll'),
#  ('HEYITS_TOBY', 'RightTroll'),
#  ('HIIMKHLOE', 'LeftTroll'),
#  ('HIPPPO_', 'HashtagGamer'),
#  ('HOLDMEJERRY', 'LeftTroll'),
#  ('HOLLANDPATRICKK', 'RightTroll'),
#  ('HOLLYDLER', 'RightTroll'),
#  ('HOLYCRAPCHRIX', 'HashtagGamer'),
#  ('HOUSTONTOPNEWS', 'NewsFeed'),
#  ('HUNTERODDDDOM', 'LeftTroll'),
#  ('HYDDROX', 'RightTroll'),
#  ('IANCALH0UN', 'LeftTroll'),
#  ('IGNITEDFIRESTAR', 'RightTroll'),
#  ('IIDDAAMARKS', 'LeftTroll'),
#  ('ILIKEBIGBUTTAND', 'HashtagGamer'),
#  ('ILOVESARAHRICH', 'LeftTroll'),
#  ('IMAPHARRELFAKE', 'LeftTroll'),
#  ('IMASWERVE', 'LeftTroll'),
#  ('IMISSOBAMA', 'LeftTroll'),
#  ('IMOGEENTR', 'RightTroll'),
#  ('INSTOTUS', 'RightTroll'),
#  ('INST_VETS', 'RightTroll'),
#  ('INTERFISCHER', 'RightTroll'),
#  ('ISABEL_STAFF', 'RightTroll'),
#  ('ISA_BELLA_GR', 'RightTroll'),
#  ('ISRAEL_WILLS', 'RightTroll'),
#  ('ITSTIMETOSECEDE', 'RightTroll'),
#  ('IVAASSNTR', 'RightTroll'),
#  ('J0HNLARSEN', 'RightTroll'),
#  ('JACKSONCITYPOST', 'NewsFeed'),
#  ('JACQUELINISBEST', 'RightTroll'),
#  ('JADONHUTCHINSON', 'LeftTroll'),
#  ('JAEDENMASSEY', 'LeftTroll'),
#  ('JAMIE_MCCARTHY_', 'RightTroll'),
#  ('JANELPERKINSON', 'LeftTroll'),
#  ('JANI_S_JAC', 'LeftTroll'),
#  ('JANSKEESTR', 'RightTroll'),
#  ('JARRARDNORMAN', 'HashtagGamer'),
#  ('JASPER_FLY', 'HashtagGamer'),
#  ('JASSSCOTT', 'LeftTroll'),
#  ('JAVONHIDP', 'LeftTroll'),
#  ('JAYDAASTONISHIN', 'LeftTroll'),
#  ('JEANETTEDBOLDEN', 'HashtagGamer'),
#  ('JEANNEMCCARTHY0', 'RightTroll'),
#  ('JEANUTTELLA', 'LeftTroll'),
#  ('JEBLARY2016', 'RightTroll'),
#  ('JEFFREYKAHUNAS', 'RightTroll'),
#  ('JEMISHAAAZZZ', 'LeftTroll'),
#  ('JENN_ABRAMS', 'RightTroll'),
#  ('JERSTONER', 'LeftTroll'),
#  ('JERY_ROBERTSYO', 'LeftTroll'),
#  ('JESSYBOWWOW', 'LeftTroll'),
#  ('JIHADIST2NDWIFE', 'RightTroll'),
#  ('JMCD0WELL', 'RightTroll'),
#  ('JMSCOXXX', 'HashtagGamer'),
#  ('JOHAAJOTS', 'RightTroll'),
#  ('JOHNBRANCHH', 'LeftTroll'),
#  ('JOHNCOPPER16', 'RightTroll'),
#  ('JOHNIEBOYCOOKS', 'LeftTroll'),
#  ('JOHNIEVOGUE', 'LeftTroll'),
#  ('JOHNNYMARCH_', 'LeftTroll'),
#  ('JON_UNDERWOOD_', 'RightTroll'),
#  ('JOSEPH_JENKS', 'RightTroll'),
#  ('JOTEFOKIS', 'RightTroll'),
#  ('JSHMRTNEZ', 'Fearmonger'),
#  ('JSNCAREY', 'RightTroll'),
#  ('JUANTHOMSSTRUMT', 'RightTroll'),
#  ('JUDELAMBERTUSA', 'RightTroll'),
#  ('JUSMASXTRT', 'RightTroll'),
#  ('JUSTBE_MINE', 'Fearmonger'),
#  ('KAHALEETR', 'RightTroll'),
#  ('KANIJJACKSON', 'LeftTroll'),
#  ('KANSASDAILYNEWS', 'NewsFeed'),
#  ('KARENPARKER93', 'RightTroll'),
#  ('KARMAISABITCHH1', 'RightTroll'),
#  ('KATEDEBROOK', 'RightTroll'),
#  ('KATERITTERRRR', 'RightTroll'),
#  ('KATHIEMRR', 'HashtagGamer'),
#  ('KAYDENMELTON', 'LeftTroll'),
#  ('KELVIN_CHAMBERS', 'RightTroll'),
#  ('KENCANNONE', 'HashtagGamer'),
#  ('KENDRAGRRR', 'RightTroll'),
#  ('KENZDONOVAN', 'RightTroll'),
#  ('KIRSTENLADANIEL', 'RightTroll'),
#  ('KRISTYANANN', 'HashtagGamer'),
#  ('LACHRISTIE', 'RightTroll'),
#  ('LAGONEHOE', 'LeftTroll'),
#  ('LARAHARRRRISON', 'RightTroll'),
#  ('LAURABAELEY', 'RightTroll'),
#  ('LAWWAANCTR', 'RightTroll'),
#  ('LAZYKSTAFFORD', 'RightTroll'),
#  ('LELANDGRAVES_', 'RightTroll'),
#  ('LEROYLOVESUSA', 'RightTroll'),
#  ('LGBTUNI', 'LeftTroll'),
#  ('LGBTUNITEDCOM', 'LeftTroll'),
#  ('LILAASTRS', 'RightTroll'),
#  ('LILJORDAMN', 'LeftTroll'),
#  ('LIRASTERTTRUMP', 'RightTroll'),
#  ('LNEVER_MINDL', 'Fearmonger'),
#  ('LOGAN_WHATSUP', 'RightTroll'),
#  ('LOLA_AYERS_', 'RightTroll'),
#  ('LOOKATMEZERO', 'RightTroll'),
#  ('LORAGREEEN', 'HashtagGamer'),
#  ('LUCEELYSTOP', 'Unknown'),
#  ('LUCYTRUMPTTOP56', 'RightTroll'),
#  ('LUGHHALLEY', 'HashtagGamer'),
#  ('LUZMARTRUMPPT', 'RightTroll'),
#  ('LYNDAWKING', 'HashtagGamer'),
#  ('LYNSRODRIGUEZ', 'HashtagGamer'),
#  ('MALLBOWEN', 'RightTroll'),
#  ('MALLORYJARED', 'LeftTroll'),
#  ('MANDY9STEVENS', 'RightTroll'),
#  ('MANZAL_', 'NonEnglish'),
#  ('MAORBRIGHTIE', 'RightTroll'),
#  ('MARCH_FOR_TRUMP', 'RightTroll'),
#  ('MARIALOPTRUMP', 'RightTroll'),
#  ('MARIATRUMPT', 'RightTroll'),
#  ('MARISSAIMSTRONG', 'RightTroll'),
#  ('MARISSPRT', 'RightTroll'),
#  ('MARKMCGREGORY', 'RightTroll'),
#  ('MARLEY_SHN', 'Fearmonger'),
#  ('MARRISSATRR', 'RightTroll'),
#  ('MARTINES_TWEETS', 'Fearmonger'),
#  ('MARTINIVINE', 'RightTroll'),
#  ('MATEVIDENCE', 'NewsFeed'),
#  ('MAYLUUSSTR', 'RightTroll'),
#  ('MAYMAYMYY', 'LeftTroll'),
#  ('MEGGIEONEIL', 'HashtagGamer'),
#  ('MELANYMELANIN', 'LeftTroll'),
#  ('MELVINSROBERTS', 'HashtagGamer'),
#  ('MEMYSELFHAILEY', 'Unknown'),
#  ('MICHELLEARRY', 'RightTroll'),
#  ('MICPARRISH', 'RightTroll'),
#  ('MIL0BLAKE', 'RightTroll'),
#  ('MILWAUKEEVOICE', 'NewsFeed'),
#  ('MINNEAPOLISON', 'NewsFeed'),
#  ('MISSOURINEWSUS', 'RightTroll'),
#  ('MOM_0F_TWINS', 'RightTroll'),
#  ('MONEYFORM', 'RightTroll'),
#  ('MRCLYDEPRATT', 'LeftTroll'),
#  ('MRJACKSJACKSON', 'RightTroll'),
#  ('MRMORAAN', 'LeftTroll'),
#  ('MR_CLAMPIN', 'HashtagGamer'),
#  ('MSHEATHOWENS', 'RightTroll'),
#  ('MUHAMMADMUSA23', 'NonEnglish'),
#  ('MUHSANSINS', 'NonEnglish'),
#  ('MUSLIMS_IN_USA', 'LeftTroll'),
#  ('NEHEMIAHX', 'LeftTroll'),
#  ('NEVERLIET0ME', 'NewsFeed'),
#  ('NEWARKVOICE', 'NewsFeed'),
#  ('NEWORLEANSON', 'NewsFeed'),
#  ('NEWSPEAKDAILY', 'NewsFeed'),
#  ('NEWYORKDEM', 'LeftTroll'),
#  ('NJ_BLACKNEWS', 'LeftTroll'),
#  ('NOJONATHONNO', 'LeftTroll'),
#  ('NORMAN_HOOPER', 'Fearmonger'),
#  ('NOTBALLINYET', 'LeftTroll'),
#  ('NOTRITAHART', 'HashtagGamer'),
#  ('NOVOSTILAVROV', 'NonEnglish'),
#  ('OAKLANDONLINE', 'NewsFeed'),
#  ('OGDEANDRE', 'LeftTroll'),
#  ('OLIVIA1GB', 'RightTroll'),
#  ('OLIVIADWARREN', 'LeftTroll'),
#  ('ONEMIGHTYFISH', 'LeftTroll'),
#  ('ONLINECLEVELAND', 'NewsFeed'),
#  ('ONLINEMEMPHIS', 'NewsFeed'),
#  ('ORRCLAY', 'RightTroll'),
#  ('OSCAR_ROWE_', 'RightTroll'),
#  ('PAIGE_JAM', 'RightTroll'),
#  ('PAMBLMDANIELS', 'LeftTroll'),
#  ('PAMELAKEALER13', 'RightTroll'),
#  ('PAMELA_MOORE13', 'RightTroll'),
#  ('PAMELA_SHARKY13', 'RightTroll'),
#  ('PAOLAKINCK', 'RightTroll'),
#  ('PATI_COOPER', 'RightTroll'),
#  ('PATRIOTBLAKE', 'RightTroll'),
#  ('PATRIOTOTUS', 'RightTroll'),
#  ('PAULINETT', 'LeftTroll'),
#  ('PEYTONCASHOUT', 'LeftTroll'),
#  ('PHILADELPHIAON', 'NewsFeed'),
#  ('PHOENIXDAILYNEW', 'NewsFeed'),
#  ('PIGEONTODAY', 'RightTroll'),
#  ('POLICESTATEME', 'LeftTroll'),
#  ('POLIGRAPHME', 'Unknown'),
#  ('POLITWEECS', 'RightTroll'),
#  ('PORTMELA', 'RightTroll'),
#  ('PRETTYLARAPLACE', 'RightTroll'),
#  ('PRETTYSASHAH', 'RightTroll'),
#  ('PRICEFORPIERCE', 'RightTroll'),
#  ('PROJECTLANDY', 'Unknown'),
#  ('PRUITT_LI', 'Fearmonger'),
#  ('PUREDAVIE', 'HashtagGamer'),
#  ('QUEENNARIELLE', 'LeftTroll'),
#  ('QUEENOFTHEWO', 'HashtagGamer'),
#  ('RADEKESOFIA', 'Fearmonger'),
#  ('RAMONASNAILS', 'LeftTroll'),
#  ('RANDOLPHBURRR', 'LeftTroll'),
#  ('RAVENICHOLSON', 'LeftTroll'),
#  ('REACHITDOIT', 'RightTroll'),
#  ('REALROBERT1987', 'RightTroll'),
#  ('REALTEN_GOP', 'RightTroll'),
#  ('REDLANEWS', 'RightTroll'),
#  ('REGIEBLACKMON', 'LeftTroll'),
#  ('RESISTERSUNION', 'LeftTroll'),
#  ('RH0LBR00K', 'RightTroll'),
#  ('RICHMONDVOICE', 'NewsFeed'),
#  ('RIGHTNPR', 'RightTroll'),
#  ('RIOGITHIEF', 'RightTroll'),
#  ('RISSTYTRT', 'RightTroll'),
#  ('RLOVENOSAUSE', 'RightTroll'),
#  ('ROBERTEBONYKING', 'LeftTroll'),
#  ('ROBIN_MC_CALL', 'Fearmonger'),
#  ('ROOMOFRUMOR', 'NewsFeed'),
#  ('ROSCOE_RIDDLE', 'RightTroll'),
#  ('ROSSIROSSIVIN', 'NonEnglish'),
#  ('RUS_IN_USA', 'NonEnglish'),
#  ('RYANMAXWELL_1', 'RightTroll'),
#  ('SADIEEATONN', 'LeftTroll'),
#  ('SAMIRGOODEN', 'LeftTroll'),
#  ('SANANTOTOPNEWS', 'NewsFeed'),
#  ('SCARLETTHOWAR15', 'RightTroll'),
#  ('SCREAMIN3', 'NonEnglish'),
#  ('SCREAMYMONKEY', 'NewsFeed'),
#  ('SEATTLE_POST', 'NewsFeed'),
#  ('SERGIO_MAESTRI', 'NonEnglish'),
#  ('SHEENA_OTT', 'RightTroll'),
#  ('SHERLYMONMONC', 'RightTroll'),
#  ('SHINEPHILLIPS', 'Fearmonger'),
#  ('SICCERTHANYOU', 'LeftTroll'),
#  ('SIENNASMM', 'Fearmonger'),
#  ('SINCEREPRUITT', 'LeftTroll'),
#  ('SINDYBLOSSOM', 'Unknown'),
#  ('SKWAD55_LABEL', 'LeftTroll'),
#  ('SOUTHLONESTAR', 'RightTroll'),
#  ('SPECIALAFFAIR', 'NewsFeed'),
#  ('SRAHSE', 'HashtagGamer'),
#  ('SSABRINAHUH', 'RightTroll'),
#  ('SSUS_PANTHER', 'RightTroll'),
#  ('STACEWATERS_', 'Unknown'),
#  ('STANLEYPARRIS', 'LeftTroll'),
#  ('STANLEY_COX_', 'RightTroll'),
#  ('STAYWOKE88', 'LeftTroll'),
#  ('STINSON_SS', 'RightTroll'),
#  ('STLOUISONLINE', 'NewsFeed'),
#  ('SUNSANB', 'Fearmonger'),
#  ('SUSAYUNG', 'LeftTroll'),
#  ('SWEETKERRY54', 'Fearmonger'),
#  ('T0NYASINCLAIR', 'HashtagGamer'),
#  ('TAMMY_TAMH', 'Fearmonger'),
#  ('TEN_GOP', 'RightTroll'),
#  ('TERESA_BOY_LE', 'Fearmonger'),
#  ('TESSYELMORE', 'LeftTroll'),
#  ('TESS_SNIDER', 'HashtagGamer'),
#  ('THEFOUNDINGSON', 'RightTroll'),
#  ('THELMMISB', 'RightTroll'),
#  ('THEMANMACHINE17', 'RightTroll'),
#  ('THETRAINGUY13', 'RightTroll'),
#  ('TODAYBOSTONMA', 'NewsFeed'),
#  ('TODAYCINCINNATI', 'NewsFeed'),
#  ('TODAYCLEVELAND', 'NewsFeed'),
#  ('TODAYINSYRIA', 'NewsFeed'),
#  ('TODAYMIAMI', 'NewsFeed'),
#  ('TODAYNYCITY', 'NewsFeed'),
#  ('TODAYPITTSBURGH', 'NewsFeed'),
#  ('TOLLIVERSTEPH', 'Fearmonger'),
#  ('TONEPORTER', 'HashtagGamer'),
#  ('TPARTYNEWS', 'RightTroll'),
#  ('TRACEYHAPPYMOM', 'HashtagGamer'),
#  ('TRAYNESHACOLE', 'LeftTroll'),
#  ('TRYTOFINDITOUT', 'HashtagGamer'),
#  ('USA_GUNSLINGER', 'RightTroll'),
#  ('VA_BLACKNEWS', 'LeftTroll'),
#  ('VEROSANRRT', 'RightTroll'),
#  ('VESTIZAKHAROVA', 'NonEnglish'),
#  ('WADEHARRIOT', 'RightTroll'),
#  ('WARFAREWW', 'NewsFeed'),
#  ('WASHINGTONLINE', 'NewsFeed'),
#  ('WATCHMEWALKIN', 'LeftTroll'),
#  ('WAYNE_DRAKE_', 'RightTroll'),
#  ('WESTERNWINDWES', 'RightTroll'),
#  ('WILDHAREE', 'HashtagGamer'),
#  ('WILLIAMS8KALVIN', 'LeftTroll'),
#  ('WILLIAMS_DIANA_', 'RightTroll'),
#  ('WILLISBONNERR', 'LeftTroll'),
#  ('WOKEFROMDAY1', 'LeftTroll'),
#  ('WOKELUISA', 'LeftTroll'),
#  ('WONDERHANN', 'RightTroll'),
#  ('WORLDNEWSPOLI', 'RightTroll'),
#  ('WORLDOFHASHTAGS', 'HashtagGamer'),
#  ('XDWILLIE', 'RightTroll'),
#  ('YAELTROUBLE', 'HashtagGamer'),
#  ('YOUJUSTCTRLC', 'LeftTroll'),
#  ('ZZARACROSS', 'Fearmonger'),
#  ('ZZZACHARYZZZ', 'LeftTroll'),
#  ('_BILLY_MOYER_', 'RightTroll'),
#  ('_NICKLUNA_', 'RightTroll'),
#  ('_RUBY_WILLS_', 'RightTroll')]

# %%
true_labels
# Out:
# ['RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'NonEnglish',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'NewsFeed',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NonEnglish',
#  'RightTroll',
#  'Fearmonger',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'Commercial',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'LeftTroll',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'RightTroll',
#  'Fearmonger',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'RightTroll',
#  'Fearmonger',
#  'Fearmonger',
#  'LeftTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'Commercial',
#  'Fearmonger',
#  'HashtagGamer',
#  'LeftTroll',
#  'LeftTroll',
#  'Commercial',
#  'LeftTroll',
#  'Fearmonger',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'Commercial',
#  'HashtagGamer',
#  'Fearmonger',
#  'Fearmonger',
#  'Fearmonger',
#  'LeftTroll',
#  'RightTroll',
#  'Fearmonger',
#  'Fearmonger',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'LeftTroll',
#  'Unknown',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'LeftTroll',
#  'NonEnglish',
#  'RightTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'Fearmonger',
#  'HashtagGamer',
#  'Fearmonger',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'NewsFeed',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'HashtagGamer',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'LeftTroll',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'Unknown',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'NonEnglish',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'Fearmonger',
#  'RightTroll',
#  'NewsFeed',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'HashtagGamer',
#  'Unknown',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'NonEnglish',
#  'NonEnglish',
#  'LeftTroll',
#  'LeftTroll',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'Fearmonger',
#  'LeftTroll',
#  'HashtagGamer',
#  'NonEnglish',
#  'NewsFeed',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'NewsFeed',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'NewsFeed',
#  'NewsFeed',
#  'RightTroll',
#  'LeftTroll',
#  'Unknown',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'Unknown',
#  'Fearmonger',
#  'HashtagGamer',
#  'LeftTroll',
#  'HashtagGamer',
#  'Fearmonger',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'NewsFeed',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'LeftTroll',
#  'Fearmonger',
#  'NewsFeed',
#  'RightTroll',
#  'NonEnglish',
#  'NonEnglish',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'NewsFeed',
#  'RightTroll',
#  'NonEnglish',
#  'NewsFeed',
#  'NewsFeed',
#  'NonEnglish',
#  'RightTroll',
#  'RightTroll',
#  'Fearmonger',
#  'LeftTroll',
#  'Fearmonger',
#  'LeftTroll',
#  'Unknown',
#  'LeftTroll',
#  'RightTroll',
#  'NewsFeed',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'Unknown',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'NewsFeed',
#  'Fearmonger',
#  'LeftTroll',
#  'Fearmonger',
#  'HashtagGamer',
#  'Fearmonger',
#  'RightTroll',
#  'Fearmonger',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'NewsFeed',
#  'Fearmonger',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'LeftTroll',
#  'RightTroll',
#  'NonEnglish',
#  'RightTroll',
#  'NewsFeed',
#  'NewsFeed',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'RightTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'HashtagGamer',
#  'RightTroll',
#  'HashtagGamer',
#  'LeftTroll',
#  'Fearmonger',
#  'LeftTroll',
#  'RightTroll',
#  'RightTroll',
#  'RightTroll']

# %%
class TrollTfidfVectorizer(TfidfVectorizer):

    def __init__(self, *args, **kwargs):
        troll_stop_words = {'don', 'just', 'like'} # the custom stop word list could be further expanded
        kwargs['stop_words'] = set(ENGLISH_STOP_WORDS).union(troll_stop_words)
        kwargs['preprocessor'] = self.vectorizer_preprocess
        self.wnl = WordNetLemmatizer()
        super(TrollTfidfVectorizer, self).__init__(*args, **kwargs)

    def build_analyzer(self):
        analyzer = super(TfidfVectorizer, self).build_analyzer()
        return lambda doc: ([self.wnl.lemmatize(w) for w in analyzer(doc)])

    def vectorizer_preprocess(self, s):
        # remove urls
        s = re.sub(r'(https?|ftp)://(-\.)?([^\s/?\.#-]+\.?)+(/[^\s]*)?', '', s)
        # remove amp
        s = s.replace('&amp;', '')
        # remove RT signs (no meaning) but keep username
        s = re.sub(r'\bRT\b\s+', '', s)
        s = s.lower()
        return s

# %%
origVectorized=TrollTfidfVectorizer().fit_transform(documents_dict.values())
origVectorized
# Out:
# <578x902648 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3903277 stored elements in Compressed Sparse Row format>

# %%
vectorizer = TrollTfidfVectorizer(max_features=MAX_FEATURES, min_df=MIN_DF)
doc_term_matrix = vectorizer.fit_transform(documents_dict.values())
doc_term_matrix
# Out:
# <578x2956 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1000911 stored elements in Compressed Sparse Row format>

# %%
if doc_term_matrix.shape[1] > MAX_WORDS_WORDCLOUD:
    print("Dimensionality is too high, consider increasing MIN_DF or decreasing MAX_FEATURES")
# Out:
# Dimensionality is too high, consider increasing MIN_DF or decreasing MAX_FEATURES

# %% [markdown]
# # Choosing the optimal number of clusters
# In the original experiment, this phase resulted in a short listing of five and six clusters

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as pl

model_scores = [] # "-within-cluster sum of squares" (the higher the better fit - because it is negative)

# value near +1 indicate that the sample is far away from the neighboring clusters.
# A value of 0 indicates that the sample is on or very close to the decision boundary between two neighboring clusters
# negative values indicate that those samples might have been assigned to the wrong cluster
model_silhouettes = [] 

clusters_range = range(2, 30)

# test cluster sizes
for n_clusters in clusters_range:
    print(f'Test clustering with {n_clusters}')

    model = KMeans(n_clusters=n_clusters, init='k-means++', n_init=1)
    cluster_labels = model.fit_predict(doc_term_matrix)

    score = model.score(doc_term_matrix)
    print(f'Model score is {model.score(doc_term_matrix)}')
    model_scores.append(score)

    silhouette_avg = silhouette_score(doc_term_matrix, cluster_labels)
    model_silhouettes.append(silhouette_avg)
    print(f'Avg silhouette score is {silhouette_avg}')
# Out:
# Test clustering with 2
# Model score is -311.2760282012585
# Avg silhouette score is 0.12132219724305436
# Test clustering with 3
# Model score is -290.76186068063896
# Avg silhouette score is 0.14656680301995517
# Test clustering with 4
# Model score is -268.47943212167695
# Avg silhouette score is 0.12791364708859787
# Test clustering with 5
# Model score is -252.24045994948023
# Avg silhouette score is 0.1619083835806023
# Test clustering with 6
# Model score is -245.90111467314205
# Avg silhouette score is 0.15869900708621262
# Test clustering with 7
# Model score is -219.40311822051967
# Avg silhouette score is 0.20297927126086215
# Test clustering with 8
# Model score is -219.88556323583904
# Avg silhouette score is 0.1645847216815024
# Test clustering with 9
# Model score is -210.45847495324094
# Avg silhouette score is 0.15152333301780216
# Test clustering with 10
# Model score is -206.5501863740244
# Avg silhouette score is 0.1544891418902
# Test clustering with 11
# Model score is -199.81815031106896
# Avg silhouette score is 0.1682939301016441
# Test clustering with 12
# Model score is -195.63469728801448
# Avg silhouette score is 0.17339956551490973
# Test clustering with 13
# Model score is -191.25403676739802
# Avg silhouette score is 0.1759314169687706
# Test clustering with 14
# Model score is -186.98262193906618
# Avg silhouette score is 0.1738542868865233
# Test clustering with 15
# Model score is -183.57487976412426
# Avg silhouette score is 0.17967791085947923
# Test clustering with 16
# Model score is -181.08651134689774
# Avg silhouette score is 0.18254084254579309
# Test clustering with 17
# Model score is -179.9522116426621
# Avg silhouette score is 0.17030031970078843
# Test clustering with 18
# Model score is -176.29554052767105
# Avg silhouette score is 0.17577870043019103
# Test clustering with 19
# Model score is -172.4614731323072
# Avg silhouette score is 0.19011016294051192
# Test clustering with 20
# Model score is -172.27885438800408
# Avg silhouette score is 0.1740638999764966
# Test clustering with 21
# Model score is -168.1753755721565
# Avg silhouette score is 0.1653041150153415
# Test clustering with 22
# Model score is -165.30184989162103
# Avg silhouette score is 0.15716691366718993
# Test clustering with 23
# Model score is -161.20059590473267
# Avg silhouette score is 0.191939369462846
# Test clustering with 24
# Model score is -162.3448369903612
# Avg silhouette score is 0.14609611969408828
# Test clustering with 25
# Model score is -160.2092549674498
# Avg silhouette score is 0.17677136832887275
# Test clustering with 26
# Model score is -158.92199275379534
# Avg silhouette score is 0.17526124671644397
# Test clustering with 27
# Model score is -156.57437932299186
# Avg silhouette score is 0.14745806983437507
# Test clustering with 28
# Model score is -152.27585366714015
# Avg silhouette score is 0.1898569391221635
# Test clustering with 29
# Model score is -154.20080531093748
# Avg silhouette score is 0.1468000038027259

# %% [markdown]
# # Elbow curve

# %%
pl.plot(clusters_range, model_scores)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

pl.plot(clusters_range, model_silhouettes)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Average Silhouette score')
pl.show()

# %% [markdown]
# # Evaluation of clustering combinations and selection of the best

# %% [markdown]
# Finds the best combination and selects it

# %%
# Metrics                    
from sklearn.metrics import adjusted_rand_score,\
    silhouette_score, davies_bouldin_score,\
    calinski_harabasz_score, v_measure_score, fowlkes_mallows_score

def evalCluster(doc_term_matrix,cluster_labels,true_labels, tag):
    silhouette_avg = silhouette_score(doc_term_matrix, cluster_labels)  #smaller value better
    db_index = davies_bouldin_score(data, cluster_labels)# greater value better
    vrc = calinski_harabasz_score(data, cluster_labels) #smaller value better
    adjusted_rand = adjusted_rand_score(true_labels, cluster_labels) #smaller value better
    v_measure = v_measure_score(true_labels, cluster_labels) #smaller value better
    fm_score = fowlkes_mallows_score(true_labels, cluster_labels)  #smaller value better
    return (pd.DataFrame([silhouette_avg,db_index,vrc,adjusted_rand,v_measure,fm_score], columns=[tag],index=["silhouette_avg","db_index","vrc","adjusted_rand","v_measure","fm_score"]))

# %%
#def l2norm(doc_term_matrix):
    #the data on input are already l2 normalized
    #https://stackoverflow.com/questions/46409846/using-k-means-with-cosine-similarity-python
#    length = np.sqrt((doc_term_matrix**2).sum(axis=1))[:,None]
#    data = doc_term_matrix / length
#    data=np.nan_to_num(data)
#    return(data)

# %%
import numpy as np
from itertools import compress
zerorows=np.where(np.sum(np.abs(doc_term_matrix), axis=1)==0)[0]
if zerorows.size>0:
    nonzerovectors=doc_term_matrix.getnnz(1)!=0
    print("removing entries with all zero feature vectors")
    print(zerorows)
    doc_term_matrix= doc_term_matrix[nonzerovectors]
    cluster_labels=cluster_labels[nonzerovectors]
    true_labels = list(compress(true_labels, nonzerovectors))

# %%
import numpy as np
data=doc_term_matrix.toarray()
from nltk.cluster import KMeansClusterer, cosine_distance
import random
dfStats = pd.DataFrame(index=["silhouette_avg","db_index","vrc","adjusted_rand","v_measure","fm_score"], columns=[])
models=[]
for n_clusters in CLUSTERS_TO_TRY:
    for distance in ["euclidean","cosine"]:
        for init in ["k-means++","random"]:
            tag=init+ str(n_clusters) + distance
            seed=42    
            if distance=="cosine":
                if init == "k-means++":
                    continue #this combination is not supported
                rng = random.Random()
                rng.seed(seed)
                model = KMeansClusterer(n_clusters, distance=cosine_distance,repeats=25, avoid_empty_clusters=True,  rng = rng)  
                cluster_labels = model.cluster(data, assign_clusters=True)
            else:
                model = KMeans(n_clusters=n_clusters, random_state=seed, init=init, n_init=25)
                model = model.fit(data)
                cluster_labels = model.predict(data)
            models.append(model)
            _df=evalCluster(data,cluster_labels,true_labels, tag)
            dfStats=pd.concat([dfStats,_df], axis=1)

# %%
dfStats
# Out:
#                 k-means++5euclidean  random5euclidean  random5cosine  \
# silhouette_avg             0.173163          0.170275       0.175477
# db_index                   2.186405          2.187754       2.202398
# vrc                       66.878338         66.875809      60.072605
# adjusted_rand              0.406713          0.419611       0.428549
# v_measure                  0.603884          0.592102       0.565384
# fm_score                   0.565693          0.573866       0.584763
#
#                 k-means++6euclidean  random6euclidean  random6cosine
# silhouette_avg             0.192061          0.192556       0.188935
# db_index                   2.236659          2.242302       2.025601
# vrc                       64.481958         64.460445      59.537709
# adjusted_rand              0.454205          0.458246       0.514610
# v_measure                  0.659271          0.656074       0.658509
# fm_score                   0.599545          0.602701       0.647302

# %%
from sklearn.cluster import AgglomerativeClustering
for n_clusters in CLUSTERS_TO_TRY:
    for affinity in ["euclidean","cosine"]:
        for linkage in ["average","complete","single"]:
            model = AgglomerativeClustering(n_clusters=n_clusters, affinity=affinity,
                                            linkage=linkage)
            cluster_labels = model.fit_predict(data)
            models.append(model)
            _df=evalCluster(data,cluster_labels,true_labels, linkage  +str(n_clusters)+affinity)
            dfStats=pd.concat([dfStats,_df], axis=1)

# %%
# Functions for

# %% [markdown]
# ### Compute ranks

# %%
dfStats_rounded = round(dfStats,6)
dfStats_rounded #this is necessary to prevent very small differences to cause different rankings
# Out:
#                 k-means++5euclidean  random5euclidean  random5cosine  \
# silhouette_avg             0.173163          0.170275       0.175477
# db_index                   2.186405          2.187754       2.202398
# vrc                       66.878338         66.875809      60.072605
# adjusted_rand              0.406713          0.419611       0.428549
# v_measure                  0.603884          0.592102       0.565384
# fm_score                   0.565693          0.573866       0.584763
#
#                 k-means++6euclidean  random6euclidean  random6cosine  \
# silhouette_avg             0.192061          0.192556       0.188935
# db_index                   2.236659          2.242302       2.025601
# vrc                       64.481958         64.460445      59.537709
# adjusted_rand              0.454205          0.458246       0.514610
# v_measure                  0.659271          0.656074       0.658509
# fm_score                   0.599545          0.602701       0.647302
#
#                 average5euclidean  complete5euclidean  single5euclidean  \
# silhouette_avg           0.176654            0.149759          0.178133
# db_index                 1.107628            2.221717          0.964564
# vrc                      3.541514           35.938850          3.497654
# adjusted_rand            0.018339            0.355367          0.017390
# v_measure                0.074133            0.479614          0.075424
# fm_score                 0.558199            0.576510          0.558569
#
#                 average5cosine  complete5cosine  single5cosine  \
# silhouette_avg        0.176654         0.149759       0.178133
# db_index              1.107628         2.221717       0.964564
# vrc                   3.541514        35.938850       3.497654
# adjusted_rand         0.018339         0.355367       0.017390
# v_measure             0.074133         0.479614       0.075424
# fm_score              0.558199         0.576510       0.558569
#
#                 average6euclidean  complete6euclidean  single6euclidean  \
# silhouette_avg           0.177022            0.150040          0.164317
# db_index                 1.122040            1.948414          0.925757
# vrc                      3.798074           29.265361          3.157219
# adjusted_rand            0.022471            0.355447          0.020362
# v_measure                0.087931            0.482834          0.083820
# fm_score                 0.557880            0.576547          0.559453
#
#                 average6cosine  complete6cosine  single6cosine
# silhouette_avg        0.177022         0.150040       0.164317
# db_index              1.122040         1.948414       0.925757
# vrc                   3.798074        29.265361       3.157219
# adjusted_rand         0.022471         0.355447       0.020362
# v_measure             0.087931         0.482834       0.083820
# fm_score              0.557880         0.576547       0.559453

# %%
dfStats_rank=dfStats_rounded.rank(axis=1,ascending=False)
dfStats_rank.loc["db_index"] = dfStats_rounded.loc["db_index"].rank(ascending=True)

# %%
dfStats_rank
# Out:
#                 k-means++5euclidean  random5euclidean  random5cosine  \
# silhouette_avg                 11.0              12.0           10.0
# db_index                       12.0              13.0           14.0
# vrc                             1.0               2.0            5.0
# adjusted_rand                   6.0               5.0            4.0
# v_measure                       4.0               5.0            6.0
# fm_score                       10.0               9.0            4.0
#
#                 k-means++6euclidean  random6euclidean  random6cosine  \
# silhouette_avg                  2.0               1.0            3.0
# db_index                       17.0              18.0           11.0
# vrc                             3.0               4.0            6.0
# adjusted_rand                   3.0               2.0            1.0
# v_measure                       1.0               3.0            2.0
# fm_score                        3.0               2.0            1.0
#
#                 average5euclidean  complete5euclidean  single5euclidean  \
# silhouette_avg                8.5                17.5               4.5
# db_index                      5.5                15.5               3.5
# vrc                          13.5                 7.5              15.5
# adjusted_rand                15.5                 9.5              17.5
# v_measure                    17.5                 9.5              15.5
# fm_score                     15.5                 7.5              13.5
#
#                 average5cosine  complete5cosine  single5cosine  \
# silhouette_avg             8.5             17.5            4.5
# db_index                   5.5             15.5            3.5
# vrc                       13.5              7.5           15.5
# adjusted_rand             15.5              9.5           17.5
# v_measure                 17.5              9.5           15.5
# fm_score                  15.5              7.5           13.5
#
#                 average6euclidean  complete6euclidean  single6euclidean  \
# silhouette_avg                6.5                15.5              13.5
# db_index                      7.5                 9.5               1.5
# vrc                          11.5                 9.5              17.5
# adjusted_rand                11.5                 7.5              13.5
# v_measure                    11.5                 7.5              13.5
# fm_score                     17.5                 5.5              11.5
#
#                 average6cosine  complete6cosine  single6cosine
# silhouette_avg             6.5             15.5           13.5
# db_index                   7.5              9.5            1.5
# vrc                       11.5              9.5           17.5
# adjusted_rand             11.5              7.5           13.5
# v_measure                 11.5              7.5           13.5
# fm_score                  17.5              5.5           11.5

# %%
#all measures
dfStats_rank.mean()
# Out:
# k-means++5euclidean     7.333333
# random5euclidean        7.666667
# random5cosine           7.166667
# k-means++6euclidean     4.833333
# random6euclidean        5.000000
# random6cosine           4.000000
# average5euclidean      12.666667
# complete5euclidean     11.166667
# single5euclidean       11.666667
# average5cosine         12.666667
# complete5cosine        11.166667
# single5cosine          11.666667
# average6euclidean      11.000000
# complete6euclidean      9.166667
# single6euclidean       11.833333
# average6cosine         11.000000
# complete6cosine         9.166667
# single6cosine          11.833333
# dtype: float64

# %% [markdown]
# # Purity and Silhouette for the selected clustering

# %%
def predict_uni(model,data):
    if hasattr(model, 'predict'): #in kmeans
        cluster_labels = model.predict(data)
    elif hasattr(model, 'fit_predict'): #Agglo clustering does not have predict, but relearning should give the same result as there is no random state
        cluster_labels = model.fit_predict(data) 
    else: #nltk
        cluster_labels = np.array(model.cluster(data, assign_clusters=True))
    return(cluster_labels)

# %%
from sklearn import metrics
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
np.round(np.array([1,2]),2)
# Out:
# array([1, 2])

# %%
from sklearn.metrics import silhouette_samples
def purity_silhouette(data,cluster_labels,true_labels):
    sil=silhouette_samples(data, cluster_labels)
    silbycluster=[]
    purbycluster=[]
    for i in np.unique(cluster_labels):
        silbycluster.append(np.mean(sil[cluster_labels==i]))
        purbycluster.append(purity_score(np.array(true_labels)[cluster_labels==i],cluster_labels[cluster_labels==i]))
    silbycluster     = np.round(np.array(silbycluster),2)
    purbycluster     = np.round(np.array(purbycluster),2)
    return(pd.DataFrame([silbycluster,purbycluster], index=["silhouette","purity"]))

# %%
def contingencytable (dataset_to_process,cluster_labels,true_labels,exportpath):
    if dataset_to_process == "LINVILL":
       colors = ["blue","pink","black","green","yellow","violet","red","grey"]
    else:
        colors=['red','blue','green']
    df = pd.DataFrame({'cluster': cluster_labels,
                       'category': true_labels})
    newdf=df.groupby(by=["cluster","category"]).size().unstack().reset_index().drop("cluster",axis=1)
    newdf = newdf.rename_axis("cluster",axis="columns")
    ax = newdf.plot.bar(stacked=True,color=colors)
    ax.set_ylabel("account count")
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
              fancybox=True, shadow=True, ncol=5)
    ax.figure.savefig(f"{exportpath}.pdf",bbox_inches='tight')

# %% [markdown]
# # visualization definitions

# %%
# Word clouds
from wordcloud import WordCloud
import matplotlib.pyplot as pl

# this function is used both for standard word clouds and z-score word clouds
def wordcloud(dataframe, path, spectral=False, max_words=200,vertical =2,  horizontal =3):
    if dataframe.shape[0] == 5:
        vertical =1
        horizontal =5
    
    clusters_word_freq = []

    for index, row in dataframe.iterrows():
        freq_dict = {}
        for col_name in dataframe.columns:
            if row[col_name] > 0.00001:
                freq_dict[col_name] = float(row[col_name])
        clusters_word_freq.append(freq_dict)

    fig = pl.figure(figsize=(20, 10))
    for cluster, freq_dict in enumerate(clusters_word_freq):
        if spectral: #used for wordclouds from zscores, coolwarm goes from blue to red 
            def color_func(word, *args, **kwargs):
                cmap = pl.cm.get_cmap('coolwarm')
                #Colormap instances are used to convert data values (floats) from the interval [0, 1] to the RGBA color
                rgb = cmap(freq_dict[word] / 100, bytes=True)[0:3]                    
                return rgb
        else:
            color_func = None

        ax = fig.add_subplot(vertical, horizontal, cluster + 1)
        cloud = WordCloud(normalize_plurals=False,
                          background_color='white', color_func=color_func,max_words=max_words, random_state=42)
        #classwordcloud.WordCloud(font_path=None, width=400, height=200, margin=2, ranks_only=None, prefer_horizontal=0.9, mask=None, scale=1, color_func=None, max_words=200, min_font_size=4, stopwords=None, random_state=None, background_color='black', max_font_size=None, font_step=1, mode='RGB', relative_scaling='auto', regexp=None, collocations=True, colormap=None, normalize_plurals=True, contour_width=0, contour_color='black', repeat=False, include_numbers=False, min_word_length=0, collocation_threshold=30)
        cloud.generate_from_frequencies(frequencies=freq_dict)
        ax.imshow(cloud, interpolation='bilinear')
        ax.set_yticks([])
        ax.set_xticks([])
        ax.text(0.35, 1, f'Cluster {cluster}',
                 fontsize=32, va='bottom',transform=ax.transAxes)
    fig.show()
    ax.figure.savefig(path+'.pdf',bbox_inches='tight')

# %%
import matplotlib.pyplot as pl
from pandas import concat

def zscore_barchart(dataframe, path, term_count=10):

    fig = pl.figure(figsize=(15, 20))
    # iterate through clusters
    for i in range(dataframe.shape[0]):
        #weight vector for current cluster as one column
        cluster_df = dataframe.iloc[[i]].T
        cluster_df = cluster_df.rename(index=str, columns={i: 'Z-score'})
        cluster_df = cluster_df.sort_values(by=['Z-score'])
        if term_count: #uses default value of 10
            half_term_count = term_count // 2
            #uses five biggest and five smallest values
            sliced_df = concat([cluster_df[:half_term_count],
                                cluster_df[-half_term_count:]])
        else:
            sliced_df = cluster_df

        high_df = sliced_df.copy()
        high_df.loc[high_df['Z-score'] < 0, 'Z-score'] = 0
        low_df = sliced_df.copy()
        low_df.loc[low_df['Z-score'] >= 0, 'Z-score'] = 0
        high_zscores = high_df['Z-score']
        low_zscores = low_df['Z-score']
        ind = sliced_df.index

        ax = fig.add_subplot(3, 2, i + 1)

        ax.barh(ind, low_zscores, label='Low')
        ax.barh(ind, high_zscores, label='High')
        ax.set_xlabel(f'Z-scores of Cluster {i}', fontsize=26)
        ax.set_ylabel('Term', fontsize=18)
        ax.tick_params(labelsize=18)
        ax.legend(prop={'size': 18})
        ax.grid(True)

    fig.subplots_adjust(hspace=0.8)
    fig.show()

# %%
from sklearn.neighbors import NearestCentroid
from scipy.stats import stats
from pandas import DataFrame
from sklearn.preprocessing import MinMaxScaler
def dfFromModel(model,vectorizer, transformation = None):
    if hasattr(model, 'cluster_centers_'): 
        cluster_centers = model.cluster_centers_
    else:
        #https://stackoverflow.com/questions/56456572/how-to-get-agglomerative-clustering-centroid-in-python-scikit-learn
        
        clf = NearestCentroid()
        clf.fit(data, cluster_labels)
        cluster_centers =clf.centroids_
    if transformation == None:
        transformed=cluster_centers
    elif transformation=="zscore" or  transformation=="zscore_rescaled":
        zscore=stats.zscore(cluster_centers, axis=0)
        if transformation=="zscore_rescaled":
            #data are flattened into one long vector
            zscore_flattened = zscore.reshape(zscore.shape[0] * zscore.shape[1], 1)
            #rescaled
            #MinMaxScaler preserves the shape of the original distribution.
            scaler = MinMaxScaler((0,100))
            # find maximum absolute z score 
            bound = max(max(zscore_flattened), abs(min(zscore_flattened)))
            # use the maximum z score to create transformation centered around 0
            scaler.fit(np.array([-bound,bound]))
            #scaler.fit(zscore_flattened) # originaly the transformation was fitted without the centering
            #owing to the centering, after the transformation, value 50 corresponds to zscore 0 
            zscore_flattened_scaled = scaler.transform(zscore_flattened)
            #and transformed back to the original shape
            zscore_scaled = zscore_flattened_scaled.reshape(zscore.shape[0], zscore.shape[1])
            transformed=zscore_scaled
        else:
            transformed=zscore
    dataframe = DataFrame(transformed,columns=vectorizer.get_feature_names())
    return(dataframe)

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Model selected based on internal measures

# %%
INTERNAL_MEASURES= ["silhouette_avg","db_index","vrc"] # This corresponds to "internal"

# %%
dfStats_rank.mean()
# Out:
# k-means++5euclidean     7.333333
# random5euclidean        7.666667
# random5cosine           7.166667
# k-means++6euclidean     4.833333
# random6euclidean        5.000000
# random6cosine           4.000000
# average5euclidean      12.666667
# complete5euclidean     11.166667
# single5euclidean       11.666667
# average5cosine         12.666667
# complete5cosine        11.166667
# single5cosine          11.666667
# average6euclidean      11.000000
# complete6euclidean      9.166667
# single6euclidean       11.833333
# average6cosine         11.000000
# complete6cosine         9.166667
# single6cosine          11.833333
# dtype: float64

# %%
ranks=dfStats_rank.loc[INTERNAL_MEASURES].mean()
bestModelId=np.argmin(ranks)
print("Best model based on INTERNAL metrics:" + ranks.index[bestModelId])
model=models[bestModelId]
cluster_labels = predict_uni(model,data)
contingencytable(dataset_to_process,cluster_labels,true_labels,"internal_"+dataset_to_process)
purity_silhouette(data,cluster_labels,true_labels)
# Out:
# Best model based on INTERNAL metrics:random6cosine
# Warning: means will be discarded for subsequent trials
#                0     1     2     3     4     5
# silhouette  0.25  0.03  0.29  0.10  0.16  0.26
# purity      0.90  0.89  0.94  0.94  0.64  0.96

# %%
wordcloud(dfFromModel(model,vectorizer),"wordclouds_"+dataset_to_process + "_INTERNAL",max_words=MAX_WORDS_WORDCLOUD)
# Out:
# <ipython-input-43-0831c22a3021>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
zscore_barchart(dfFromModel(model,vectorizer,"zscore"), "wordclouds_"+dataset_to_process+"_INTERNAL")
# Out:
# <ipython-input-44-513e6e48ef9e>:40: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
wordcloud(dfFromModel(model,vectorizer,"zscore_rescaled"),"wordclouds_z_"+dataset_to_process+"_INTERNAL", spectral=True,max_words=MAX_WORDS_WORDCLOUD)
# Out:
# <ipython-input-43-0831c22a3021>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Model selected based on all metrics

# %%
bestModelId=np.argmin(dfStats_rank.mean())
print("Best model based on ALL metrics:" + ranks.index[bestModelId])
model=models[bestModelId]
cluster_labels = predict_uni(model,data)
contingencytable(dataset_to_process,cluster_labels,true_labels,"all_"+dataset_to_process)
purity_silhouette(data,cluster_labels,true_labels)
# Out:
# Best model based on ALL metrics:random6cosine
# Warning: means will be discarded for subsequent trials
#                0     1     2     3     4     5
# silhouette  0.25  0.03  0.29  0.10  0.16  0.26
# purity      0.90  0.89  0.94  0.94  0.64  0.96

# %%
wordcloud(dfFromModel(model,vectorizer),"wordclouds_"+dataset_to_process+"_ALL",max_words=MAX_WORDS_WORDCLOUD)
# Out:
# <ipython-input-43-0831c22a3021>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
zscore_barchart(dfFromModel(model,vectorizer,"zscore"), "wordclouds_"+dataset_to_process+"_ALL")
# Out:
# <ipython-input-44-513e6e48ef9e>:40: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
wordcloud(dfFromModel(model,vectorizer,"zscore_rescaled"),"wordclouds_z_"+dataset_to_process+"_ALL", spectral=True,max_words=MAX_WORDS_WORDCLOUD)
# Out:
# <ipython-input-43-0831c22a3021>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Custom model selection

# %%
if overrideClusterSelection!=None:
    print("Overriding automatic selection")
    bestModelId = int(np.where(ranks.index==overrideClusterSelection)[0]) #reset to model found as best on the original split
    model=models[bestModelId]
    cluster_labels = predict_uni(model,data)
    contingencytable(dataset_to_process,cluster_labels,true_labels,"all")
    purity_silhouette(data,cluster_labels,true_labels)
    wordcloud(dfFromModel(model,vectorizer),"wordclouds_"+dataset_to_process+overrideClusterSelection,max_words=MAX_WORDS_WORDCLOUD)   
    zscore_barchart(dfFromModel(model,vectorizer,"zscore"), "wordclouds_"+dataset_to_process+overrideClusterSelection)
    wordcloud(dfFromModel(model,vectorizer,"zscore_rescaled"),"wordclouds_z_"+dataset_to_process+overrideClusterSelection, spectral=True,max_words=MAX_WORDS_WORDCLOUD)
# Out:
# Overriding automatic selection
# Warning: means will be discarded for subsequent trials
# <ipython-input-43-0831c22a3021>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-44-513e6e48ef9e>:40: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-43-0831c22a3021>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # Additional visualizations

# %%
if dataset_to_process == "LINVILL":
    #This dataset corresponds to the results of the same workflow as above but on a randomly generated split used for the user study.
    origAnalysis= pd.DataFrame([
    [4,12,39,24,1,2,69,5],
    [0,10,23,8,4,4,77,0],
    [0,13,0,5,18,3,2,1],
    [0,0,1,83,0,0,2,0],
    [0,2,0,5,0,3,133,1],
    [0,0,0,0,24,0,0,0]],
        columns=["Commercial","Fear mongers","Hashtag gamers","Left trolls","News feeds","Non-English","Right trolls","Unknown"]
    )
    plt = origAnalysis.plot
    ax = plt.bar(stacked=True,color= ["blue","pink","black","green","yellow","violet","red","grey"])
    ax.set_ylabel("account count")
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
              fancybox=True, shadow=True, ncol=5)
    ax.figure.savefig('contingencyLinvill.pdf',bbox_inches='tight')
